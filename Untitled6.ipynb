# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\vivek\Downloads/train_sample.csv')

# %%
df.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38             NaN
# 1  105560   25       1  17      259  2017-11-07 13:40:27             NaN
# 2  101424   12       1  19      212  2017-11-07 18:05:24             NaN
# 3   94584   13       1  13      477  2017-11-07 04:58:08             NaN
# 4   68413   12       1   1      178  2017-11-09 09:00:09             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df.shape
# Out:
# (100000, 8)

# %%
df.describe()
# Out:
#                   ip           app         device             os  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean    91255.879670      12.04788      21.771250      22.818280
# std     69835.553661      14.94150     259.667767      55.943136
# min         9.000000       1.00000       0.000000       0.000000
# 25%     40552.000000       3.00000       1.000000      13.000000
# 50%     79827.000000      12.00000       1.000000      18.000000
# 75%    118252.000000      15.00000       1.000000      19.000000
# max    364757.000000     551.00000    3867.000000     866.000000
#
#              channel  is_attributed
# count  100000.000000  100000.000000
# mean      268.832460       0.002270
# std       129.724248       0.047591
# min         3.000000       0.000000
# 25%       145.000000       0.000000
# 50%       258.000000       0.000000
# 75%       379.000000       0.000000
# max       498.000000       1.000000

# %% [markdown]
# # data cleaning

# %%
df.isnull().sum()
# Out:
# ip                     0
# app                    0
# device                 0
# os                     0
# channel                0
# click_time             0
# attributed_time    99773
# is_attributed          0
# dtype: int64

# %%
attributed_time=df['attributed_time'].mode

# %%
df['attributed_time'].fillna(value=attributed_time,inplace=True)

# %%
df.isnull().sum()
# Out:
# ip                 0
# app                0
# device             0
# os                 0
# channel            0
# click_time         0
# attributed_time    0
# is_attributed      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#how many show a app in maximum channel on a click_time
df[df['app']==df['app'].max()][['channel','click_time','device']]
# Out:
#        channel           click_time  device
# 24696      243  2017-11-07 10:39:53     347

# %%
df['channel'].value_counts()
# Out:
# 280    8114
# 245    4802
# 107    4543
# 477    3960
# 134    3224
#        ...
# 114       1
# 474       1
# 261       1
# 465       1
# 4         1
# Name: channel, Length: 161, dtype: int64

# %%
df[df['ip']==df['ip'].max()][['app','os']]
# Out:
#        app  os
# 69081    3  13

# %%
df['device'].unique
# Out:
# <bound method Series.unique of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 99995    1
# 99996    1
# 99997    1
# 99998    1
# 99999    1
# Name: device, Length: 100000, dtype: int64>

# %%
df['is_attributed'].unique
# Out:
# <bound method Series.unique of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: is_attributed, Length: 100000, dtype: int64>

# %% [markdown]
# # relationship

# %%
sns.countplot(x='is_attributed',data=df)
# Out:
# <AxesSubplot:xlabel='is_attributed', ylabel='count'>

# %%
sns.histplot(x='device',hue='is_attributed',data=df)
# Out:
# <AxesSubplot:xlabel='device', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(x='channel',data=df)
# Out:
# <AxesSubplot:xlabel='channel'>

# %%
sns.distplot(df['channel'])
# Out:
# C:\Users\vivek\anaconda3\1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='channel', ylabel='Density'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x='channel',hue='is_attributed',data=df)
# Out:
# <AxesSubplot:xlabel='channel', ylabel='Count'>

# %%
#df.drop('click_time',axis=1)

# %%
X=df.iloc[:,0:5]

# %%
X
# Out:
#            ip  app  device  os  channel
# 0       87540   12       1  13      497
# 1      105560   25       1  17      259
# 2      101424   12       1  19      212
# 3       94584   13       1  13      477
# 4       68413   12       1   1      178
# ...       ...  ...     ...  ..      ...
# 99995  124883   11       1  19      122
# 99996   85150    9       1  13      244
# 99997   18839    3       1  13       19
# 99998  114276   15       1  12      245
# 99999  119349   14       1  15      401
#
# [100000 rows x 5 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: is_attributed, Length: 100000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
treemodel=DecisionTreeClassifier(max_depth=2)

# %%
treemodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn import tree
plt.figure(figsize=(16,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'X[2] <= 0.5\ngini = 0.005\nsamples = 60000\nvalue = [59863, 137]'),
#  Text(0.25, 0.5, 'X[0] <= 202058.0\ngini = 0.172\nsamples = 326\nvalue = [295, 31]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.114\nsamples = 280\nvalue = [263, 17]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.423\nsamples = 46\nvalue = [32, 14]'),
#  Text(0.75, 0.5, 'X[1] <= 28.5\ngini = 0.004\nsamples = 59674\nvalue = [59568, 106]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.002\nsamples = 57995\nvalue = [57943, 52]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.062\nsamples = 1679\nvalue = [1625, 54]')]

# %%
y_pred=treemodel.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.99775
